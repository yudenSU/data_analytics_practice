# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("data/WIKI-AAPL.csv",  parse_dates=['Date'])

# %%
dataset.plot.line(x='Date', y="High", )
# Out:
# <AxesSubplot:xlabel='Date'>
